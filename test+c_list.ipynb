# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

url = "https://wowpedia.fandom.com/wiki/Major_characters"
html = urlopen(url).read()
soup = BeautifulSoup(html, features="html.parser")

# %%
characters = []

games = ['WC1','WC2','WC2X','WC3','WC3X','WoW','WoWBC','WoWWotLK','WoWC','WoWMoP','WoWWoD','WoWL','WoWBfA','WoWS','WoWD']

for s in soup.find_all('p'):
    text = s.text
    if "—" in text:
        
        d = {}
        
        t = text.replace("\n", "").split("—")

        name = t[0].strip().replace(" ", "_") #.replace(" ", "")

        expansions = t[1].replace(" ", "").split(",")
        expansions = [1 if i in expansions else 0 for i in games]
        
        if 1 in expansions:
            d['Name'] = name
            for i,g in enumerate(games):
                d[g] = expansions[i]
                
            characters.append(d)

# %%
df = pd.DataFrame(characters)
df.sort_values("Name").iloc[150:200]
# Out:
#                                           Name  WC1  WC2  WC2X  WC3  WC3X  \
# 85                             Magister_Umbric    0    0     0    0     0
# 44                           Magni_Bronzebeard    0    0     0    0     0
# 6                                  Magtheridon    0    0     0    0     1
# 69                            Maiev_Shadowsong    0    0     0    0     1
# 7                                    Mal'Ganis    0    0     0    1     0
# 70                         Malfurion_Stormrage    0    0     0    1     1
# 124                                    Malorne    0    0     0    0     0
# 20                                     Malygos    0    0     0    0     0
# 4                                    Mannoroth    0    0     0    1     0
# 143                         Marin_Noggenfogger    0    0     0    0     0
# 178                                     Marwyn    0    0     0    1     0
# 139                 Master_Apothecary_Faranell    0    0     0    0     0
# 261                              Master_Gadrin    0    0     0    0     0
# 254                         Mayla_Highmountain    0    0     0    0     0
# 158                                     Medivh    1    0     0    1     0
# 146                      Mekgineer_Thermaplugg    0    0     0    0     0
# 179                             Meryl_Felstorm    0    0     0    0     0
# 145                        Millhouse_Manastorm    0    0     0    0     0
# 116                                    Mimiron    0    0     0    0     0
# 205                                      Mogor    0    0     1    0     0
# 45                            Moira_Thaurissan    0    0     0    0     0
# 202                                   Mug'thol    0    0     0    0     1
# 250                             Muln_Earthfury    0    0     0    0     0
# 43                         Muradin_Bronzebeard    0    0     0    1     0
# 104                                     N'Zoth    0    0     0    0     0
# 187                      Nathanos_Blightcaller    0    0     0    0     0
# 41                                   Navarrogg    0    0     0    0     0
# 225                                    Nazgrel    0    0     0    0     1
# 28   Nefarian_(Blackwing)/Lord_Victor_Nefarius    0    0     0    0     0
# 21   Neltharion_(Deathwing)/Lord_Daval_Prestor    0    0     1    0     0
# 91                                    Neptulon    0    0     0    0     0
# 210                                   Ner'zhul    0    0     1    1     1
# 188                                Nielas_Aran    0    0     0    0     0
# 125                        Niuzao_the_Black_Ox    0    0     0    0     0
# 15                                     Nobundo    0    0     0    0     0
# 109                                  Norgannon    0    0     0    0     0
# 22                                    Nozdormu    0    0     0    0     0
# 83                                     Oculeth    0    0     0    0     0
# 117                                       Odyn    0    0     0    0     0
# 29                 Onyxia/Lady_Katrana_Prestor    0    0     0    0     0
# 211                          Orgrim_Doomhammer    0    1     1    0     0
c_list = []
for letter in tqdm(alphabet):
    url = "https://wowpedia.fandom.com/wiki/Category:Lore_characters?pagefrom={}".format(letter)
    html = urlopen(url).read()
    soup = BeautifulSoup(html, features="html.parser")
    
    for i in soup.find_all('li'):
        text = i.find('a')['href']
        verboten = ['/wiki/Genealogy', '/wiki/Local_Sitemap']
        if text[0:5] == '/wiki' and ":" not in text and text not in verboten:
            c_list.append(text.replace("%27", "'").replace("%22", '"').split("/wiki/")[1])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 26/26 [00:14<00:00,  1.75it/s]

# %%
c_list = list(set(c_list))
sorted(c_list)[1100:1200]
# Out:
# ['Narcissa',
#  'Narim',
#  'Narn_(dwarf)',
#  'Narsilla_Keensight',
#  'Narygos',
#  'Nash',
#  'Nashal',
#  'Natale',
#  "Nav'rae",
#  'Necromancer_(Terror_by_Torchlight)',
#  'Needle_(night_elf)',
#  'Neema_(orc)',
#  'Nekros_Skullcrusher',
#  'Nelara',
#  'Nelgarm',
#  'Nemuraan',
#  'Nessa_Maldy',
#  'Neva',
#  "Nez'ra",
#  'Nightsong_(horse)',
#  'Nightstalker_(wolf)',
#  'Nikeson',
#  'Nikolai',
#  'Nimbo_Zintree',
#  "Ninil'ko_the_Bloodcaller",
#  'Nipskee_Fizzwidget',
#  'Nita',
#  'Nolkai',
#  'Nori_Blackfinger',
#  'Norlan',
#  'Noroj',
#  'Norris',
#  'Not_So_Tiny_Tom',
#  'Nothgrin',
#  'Nubby_Stumpfingers',
#  'Nullyn',
#  'Nuxt_Sparklespring',
#  'Nysis',
#  "O'Ryen_Jones",
#  'Oathbreaker',
#  'Obrahiim,_the_Traveler',
#  'Obris',
#  'Oengus',
#  'Ogre_girl',
#  'Ogudei',
#  'Ohseso',
#  "Ol'_Dunken",
#  'Olaf_(human)',
#  'Old_Yoon',
#  'Olmec',
#  'Onaaka',
#  'One-Eye',
#  "Or'ligai",
#  'Orastrasz',
#  'Oreg_Earthfury',
#  'Oreil',
#  'Orgath',
#  'Orgrim_Doomhammer',
#  'Original_Harvester_of_Wrath',
#  'Orley_Post',
#  'Orman_of_Stromgarde',
#  'Ornamm',
#  'Orovinn',
#  "Oru'kai",
#  'Osgood',
#  'Otue',
#  'Ovyd',
#  'P._Diddimus',
#  'Palkar',
#  'Palleae',
#  'Pamela',
#  'Paolo',
#  'Pargath_Throatsplitter',
#  'Parsis',
#  'Pathonia_Shaw',
#  'Pebbles',
#  'Pei-Ling',
#  'Pelagosa',
#  'Penny_Flay',
#  'Peripatetic_Chou_Li',
#  'Perith_Stormhoof',
#  'Peter_Hamelspot',
#  'Pettra',
#  'Pharaoh_Tebhotep',
#  'Phillip',
#  "Phoe'be",
#  'Phyrix',
#  'Pierce',
#  'Po_Longbrow',
#  'Pooka_(rabbit)',
#  'Pratt',
#  'Private_Denning',
#  'Private_Guarding',
#  'Prophet_Kheva',
#  'Prospector_Khrona',
#  'Prospector_Soren',
#  'Pyramond',
#  'Quan_Tou_Kuo',
#  'Quenton_Miles',
#  "Quin'thatano"]

# %%
for name in c_list:
    d = {}
    d['Name'] = name
    for i,g in enumerate(games):
        d[g] = 0 
        
    characters.append(d)

# %%
df.loc[df['Name'] == 'Niuzao_the_Black_Ox']
# Out:
#                     Name  WC1  WC2  WC2X  WC3  WC3X  WoW  WoWBC  WoWWotLK  \
# 125  Niuzao_the_Black_Ox    0    0     0    0     0    0      0         0
#
#      WoWC  WoWMoP  WoWWoD  WoWL  WoWBfA  WoWS  WoWD
# 125     0       1       0     0       1     0     0

# %%
df.to_csv("df.csv", index=False)

# %%
import pickle

with open('characters.pickle', 'rb') as handle:
    characters = pickle.load(handle)
    
print(characters)
# Out:
# ['Adella', 'Admiral_Taylor', 'Advisor_Belgrum', 'Advisor_Melandrus', 'Advisor_Vandros', 'Aegira', 'Aegrim_Bronzebeard', 'Aegwynn', 'Aeonaxx', 'Aerin', 'Aerin_Stonehand', 'Aessina', 'Aethas', 'Aethas_Sunreaver', 'Agamaggan', 'Aggonar', 'Aggra', 'Aggramar', 'Ahune', 'Aiden_Perenolde', 'Akaari_Shadowgore', 'Akama', 'Akiak', "Aku'mai", 'Akunda', "Al'Akir", "Al'Akir_(tactics)#Quotes", "Al'Akir_the_Windlord", 'Alagosa', 'Alandien', 'Alard_Schmied#Quotes', 'Aldorei', 'Alexandros', 'Alexandros_Mograine', 'Alexius', 'Alexstrasza', 'Alexstrasza_the_Life-Binder', 'Aliden_Perenolde', 'Allari_the_Souleater', 'Alleria', 'Alleria_Windrunner', 'Alonsus_Faol', 'Altruis_the_Sufferer', 'Alurmi', 'Alysra', "Aman'Thul", "Aman'thul", 'Ambassador_Infernus', 'Ambassador_Slaghammer', 'Ambassador_Sunsorrow', 'Amber_Kearnen', 'Amnennar_the_Coldbringer', 'Anachronos', 'Anaris_Windwood', 'Anasterian', 'Anasterian_Sunstrider', 'Anchorite_Avuun', 'Andaris_Narassin', 'Andormu', 'Andron_Gant', 'Anduin_Lothar', 'Anduin_Wrynn', 'Anduin_Wrynn_(tactics)#Cinematic|Anduin_Raid_Finale', 'Anduin_Wrynn_(tactics)#Overview', 'Anessa', 'Anetheron', 'Ankova_the_Fallen', 'Annhylde', 'Ansirem_Runeweaver', 'Antonidas', "Anub'arak", 'Anveena', 'Anveena_Teague', 'Anvil-Thane_Thurgaden', 'Anzu', 'Aponi_Brightmane', 'Apothecary_Faustin', "Ara'lon", 'Araj', 'Aramar_Thorne', 'Arator', 'Arbiter', 'Arcanagos', 'Arcanist_Ryanna', 'Arcanist_Valtrois', 'Arcanist_Vandril', 'Arch-Desecrator_Malithar', 'Archaedas', 'Archaeologist_Andorin', 'Archbishop_Benedictus', 'Archimindy', 'Archimonde', 'Archmage_Aethas_Sunreaver', 'Archmage_Angela_Dosantos#Quotes', 'Archmage_Khadgar', "Archmage_Lan'dalock", 'Archmage_Modera', 'Arechron', 'Argus_the_Unmaker', 'Argus_the_Unmaker#Quotes', 'Arkhaan', 'Arluelle', 'Arthas', 'Arthas#Arthas_to_Magni_Bronzebeard|letter', 'Arthas_Menethil', 'Artificer_Daelo#Quotes', 'Arugal', 'Arvell', 'Arygos', "Ash'alah", 'Ashamane', 'Askara', 'Astalor_Bloodsworn', 'Astarii_Starseeker', "Atal'ai_Devoted", 'Atramedes', 'Augari_Summoner#Quotes', 'Auric_Sunchaser', 'Aurora_Skycaller', 'Avatar_of_Aggramar', 'Avatar_of_Aviana', 'Avatar_of_Hakkar', 'Aviana', 'Aviash', 'Avrus_Illwhisper', 'Azgalor', 'Azgoth', 'Azuka', 'Azuka_Bladefury', 'Azuregos', 'Azzakel', 'Azzinoth', 'Baelgun_Flamebeard', 'Baine_Bloodhoof', 'Balacgos', 'Baleroc', 'Balmedar', 'Balnazzar', 'Balnazzar_(tactics)', 'Ban-Lu', 'Ban_Bearheart', 'Banagos', 'Banshee_Queen', 'Barastagax_the_Flamecleaver', 'Barean_Westwind', 'Baron_Geddon', 'Baron_Scaldius', 'Baron_Valimar_Mordis', 'Baroness_Ninadar', 'Baroness_Vashj', "Belo'vir_Salonar", 'Belysra', 'Belysra_Starbreeze', 'Benjamin_Gibb', 'Betild_Deepanvil', 'Blackhand', 'Blacktalon_Agent', 'Blacktalon_Watcher', 'Blaithe', "Blood-Queen_Lana'thel", 'Blood_Prince_Dreven', 'Bloodeye_Redfist', 'Bloodlord_Mandokir', 'Bloodsail_Corsair', 'Bodrick_Grey', 'Bolvar_Fordragon', 'Bonesmith_Heirmir', 'Bragor_Bloodfist', 'Brann', 'Brann_Bronzebeard', 'Bria_Brightwing', 'Brigitte_Abbendis', 'Bristlefur', 'Broll', 'Broll_Bearmantle', 'Brood_Queen_Tyranna', 'Brox', 'Broxigar', 'Broxigar_the_Red', 'Brutallus', 'Brynja', 'Buniq', 'Burning_Throne_Felcaster#Quotes', 'Bwonsamdi', 'Caelestrasz', 'Cairne_Bloodhoof', 'Caladis_Brightspear', 'Calen', 'Calia_Menethil', 'Califax', 'Callie_Carrington', 'Captain_Aerthas_Firehawk', 'Captain_Delaryn_Summermoon', 'Captain_Fareeya', 'Captain_Tread_Sparknozzle', "Captain_Varo'then", 'Captain_Zalkran', 'Caretaker_WH12-B4NG', 'Caria_Felsoul', 'Carlin_Redpath', 'Carrick_Irongrin', 'Castillian', 'Cavindra', 'Celebras', 'Celebras#Quotes', 'Celosel_Nightgiver', 'Cenarius', 'Cenarius_(tactics)', 'Cesta_Stargazer', 'Chabal', 'Charlga_Razorflank', 'Chelra_the_Bladewall', 'Chen_Stormstout', 'Chi-Ji', 'Chi-Ji_(tactics)', 'Chief_Telemancer_Oculeth', 'Chieftain_Scarvash', "Cho'gall", 'Choluna#Quotes', 'Chromatus', 'Chromie', 'Chronomatic_Anomaly', 'Chronormu', 'Clintar_Dreamwalker', 'Cloudhoof', 'Commander_Gar', 'Commander_Schnottz', 'Commander_Stonebreaker', 'Commander_ ...
